# %% [markdown]
#                                      Heart Disease Dataset Analysis

# %% [markdown]
# 1.Gathering Data

# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
df = pd.read_csv("F:\heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %% [markdown]
# 2.Accessing Data

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %% [markdown]
# 3.cleaning Data

# %%
New = df.drop(columns=["target"])
New
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
New.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %% [markdown]
# Once the data is cleaned and now its time to analysis it.

# %% [markdown]
# 1. Age Analysis
#
#     Minimum and maximum ages in the dataset of heart disease.

# %%
minAge=min(New.age)
maxAge=max(New.age)
print('Min Age in the dataset is :',minAge)
print('Max Age in the dataset is :',maxAge)
# Out:
# Min Age in the dataset is : 29
# Max Age in the dataset is : 77

# %%
young_ages=New[(New.age>=29)&(New.age<40)]
middle_ages=New[(New.age>=40)&(New.age<55)]
elderly_ages=New[(New.age>55)]
print('Young Ages of people :',len(young_ages))
print('Middle Ages of people:',len(middle_ages))
print('Elderly Ages of people:',len(elderly_ages))
# Out:
# Young Ages of people : 16
# Middle Ages of people: 128
# Elderly Ages of people: 151

# %%
sns.barplot(x=['young ages','middle ages','elderly ages'],y=[len(young_ages),len(middle_ages),len(elderly_ages)])
plt.xlabel('Age Range')
plt.ylabel('Age Counts')
plt.title('Ages State in Dataset')
plt.show()

# %% [markdown]
# According to the colestrol level.

# %%
data=New[(New['chol']<200)]
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5     57    1   0       140   192    0        1      148      0      0.4
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 24    40    1   3       140   199    0        1      178      1      1.4
# 27    51    1   2       110   175    0        1      123      0      0.6
# 29    53    1   2       130   197    1        0      152      0      1.2
# 30    41    0   1       105   198    0        1      168      0      0.0
# 31    65    1   0       120   177    0        1      140      0      0.4
# 35    46    0   2       142   177    0        0      160      1      1.4
# 53    44    0   2       108   141    0        1      175      0      0.6
# 58    34    1   3       118   182    0        0      174      0      0.0
# 62    52    1   3       118   186    0        0      190      0      0.0
# ...

# %% [markdown]
# Patients having colestrol level below 200 are fit and have no heart diseases.

# %% [markdown]
# These are the first five people are fit and have no heart disease.

# %%
data=New[(New['chol']<200)]
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5     57    1   0       140   192    0        1      148      0      0.4
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 24    40    1   3       140   199    0        1      178      1      1.4
# 27    51    1   2       110   175    0        1      123      0      0.6
# 29    53    1   2       130   197    1        0      152      0      1.2
# 30    41    0   1       105   198    0        1      168      0      0.0
# 31    65    1   0       120   177    0        1      140      0      0.4
# 35    46    0   2       142   177    0        0      160      1      1.4
# 53    44    0   2       108   141    0        1      175      0      0.6
# 58    34    1   3       118   182    0        0      174      0      0.0
# 62    52    1   3       118   186    0        0      190      0      0.0
# ...

# %%
data.chol
# Out:
# 5      192
# 8      199
# 9      168
# 24     199
# 27     175
# 29     197
# 30     198
# 31     177
# 35     177
# 53     141
# 58     182
# 62     186
# 65     183
# 87     197
# 94     160
# 102    195
# 104    196
# 111    126
# 117    193
# 124    199
# 128    196
# 136    178
# 144    197
# 149    180
# 151    149
# 155    197
# 157    192
# 162    157
# 163    175
# 164    175
# 175    167
# 178    177
# 189    172
# 192    188
# 194    185
# 200    197
# 204    164
# 208    188
# 209    177
# 225    174
# 227    198
# 244    184
# 267    149
# 279    166
# 294    169
# 295    187
# 296    197
# 297    176
# 300    193
# 301    131
# Name: chol, dtype: int64

# %% [markdown]
# Levels of the heart disease according to the colestrol value.

# %%
FirstStage = New[(New.chol > 200) & (New.chol <= 239)]
FirstStage
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 10    54    1   0       140   239    0        1      160      0      1.2
# 13    64    1   3       110   211    0        0      144      1      1.8
# 15    50    0   2       120   219    0        1      158      0      1.6
# 17    66    0   3       150   226    0        1      114      0      2.6
# 19    69    0   3       140   239    0        1      151      0      1.8
# 20    59    1   0       135   234    0        1      161      0      0.5
# 21    44    1   2       130   233    0        1      179      1      0.4
# 22    42    1   0       140   226    0        1      178      0      0.0
# 26    59    1   2       150   212    1        1      157      0      1.6
# ...

# %%
FirstStage.chol
# Out:
# 0      233
# 2      204
# 3      236
# 10     239
# 13     211
# 15     219
# 17     226
# 19     239
# 20     234
# 21     233
# 22     226
# 26     212
# 32     219
# 34     213
# 37     232
# 42     208
# 46     235
# 48     216
# 49     234
# 52     231
# 55     201
# 56     222
# 63     203
# 64     211
# 66     222
# 67     234
# 68     220
# 69     209
# 71     227
# 72     204
#       ...
# 188    233
# 191    216
# 196    231
# 206    239
# 210    229
# 212    219
# 221    217
# 224    239
# 242    212
# 259    231
# 260    228
# 261    230
# 264    206
# 265    212
# 271    234
# 272    237
# 273    234
# 275    212
# 276    218
# 281    204
# 282    218
# 283    223
# 284    207
# 286    204
# 287    232
# 289    205
# 290    203
# 292    225
# 293    212
# 302    236
# Name: chol, Length: 97, dtype: int64

# %%
SecondStage = New[(New.chol > 240) & (New.chol <= 400)]
SecondStage
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 4     57    0   0       120   354    0        1      163      1      0.6
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 11    48    0   2       130   275    0        1      139      0      0.2
# 12    49    1   1       130   266    0        1      171      0      0.6
# 14    58    0   3       150   283    1        0      162      0      1.0
# 16    58    0   2       120   340    0        1      172      0      0.0
# 18    43    1   0       150   247    0        1      171      0      1.5
# 23    61    1   2       150   243    1        1      137      1      1.0
# 25    71    0   1       160   302    0        1      162      0      0.4
# 33    54    1   2       125   273    0        0      152      0      0.5
# ...

# %%
ThirdStage = New[(New.chol > 400)]
ThirdStage
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 28    65    0   2       140   417    1        0      157      0      0.8
# 85    67    0   2       115   564    0        0      160      0      1.6
# 220   63    0   0       150   407    0        0      154      0      4.0
# 246   56    0   0       134   409    0        0      150      1      1.9
#
#      slope  ca  thal
# 28       2   1     2
# 85       1   0     3
# 220      1   3     3
# 246      1   2     3

# %%
  
left = [1, 2, 3] 
  
 
height = [147,97,4] 
  

tick_label = ['FIRSTSTAGE', 'SECONDSTAGE', 'THIRDSTAGE'] 
  
plt.bar(left, height, tick_label = tick_label, 
        width = 0.8, color = ['red', 'green']) 
  

plt.xlabel('x - axis') 
 
plt.ylabel('y - axis') 
 
plt.title('CHOL LEVEL CHART') 
  

plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# According to the chest pain Type i.e cp

# %% [markdown]
# #0 Status at least(Noraml peole)
# #1 Condition slightly distressed
# #2 Condition medium problem
# #3 Condition too bad

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# According to the blood pressure

# %%
New.trestbps.value_counts()
# Out:
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    13
# 128    12
# 125    11
# 160    11
# 112     9
# 132     8
# 118     7
# 135     6
# 108     6
# 124     6
# 145     5
# 134     5
# 152     5
# 122     4
# 170     4
# 100     4
# 142     3
# 115     3
# 136     3
# 105     3
# 180     3
# 126     3
# 102     2
# 94      2
# 144     2
# 178     2
# 146     2
# 148     2
# 129     1
# 165     1
# 101     1
# 174     1
# 104     1
# 172     1
# 106     1
# 156     1
# 164     1
# 192     1
# 114     1
# 155     1
# 117     1
# 154     1
# 123     1
# 200     1
# Name: trestbps, dtype: int64

# %%
New.trestbps.value_counts().plot(kind='bar',legend=True)

# %%
b = (New['trestbps']<120).value_counts()
b
# Out:
# False    243
# True      60
# Name: trestbps, dtype: int64

# %% [markdown]
# 60 people suffering from low blood presure, which r having less than 120 bps

# %%
medium = New[(New.trestbps > 120) & (New.trestbps <= 140)]
medium
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# 12    49    1   1       130   266    0        1      171      0      0.6
# 19    69    0   3       140   239    0        1      151      0      1.8
# 20    59    1   0       135   234    0        1      161      0      0.5
# 21    44    1   2       130   233    0        1      179      1      0.4
# 22    42    1   0       140   226    0        1      178      0      0.0
# 24    40    1   3       140   199    0        1      178      1      1.4
# ...

# %%
medium.trestbps
# Out:
# 1      130
# 2      130
# 5      140
# 6      140
# 10     140
# 11     130
# 12     130
# 19     140
# 20     135
# 21     130
# 22     140
# 24     140
# 28     140
# 29     130
# 32     130
# 33     125
# 34     125
# 36     135
# 40     140
# 41     130
# 43     130
# 44     140
# 46     140
# 47     138
# 48     128
# 49     138
# 50     130
# 52     130
# 54     135
# 55     134
#       ...
# 238    125
# 239    126
# 244    132
# 245    124
# 246    134
# 249    140
# 250    140
# 251    132
# 252    138
# 256    128
# 262    123
# 268    122
# 269    130
# 271    134
# 275    125
# 277    124
# 278    136
# 279    138
# 280    136
# 281    128
# 282    126
# 284    140
# 285    140
# 286    134
# 289    128
# 295    140
# 296    124
# 298    140
# 301    130
# 302    130
# Name: trestbps, Length: 141, dtype: int64

# %%
medium.trestbps.value_counts()
# Out:
# 130    36
# 140    32
# 138    13
# 128    12
# 125    11
# 132     8
# 135     6
# 124     6
# 134     5
# 122     4
# 136     3
# 126     3
# 129     1
# 123     1
# Name: trestbps, dtype: int64

# %%
medium.trestbps.value_counts().plot(kind='pie')

# %%
high = New[(New.trestbps > 140)]
high
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 14    58    0   3       150   283    1        0      162      0      1.0
# 17    66    0   3       150   226    0        1      114      0      2.6
# 18    43    1   0       150   247    0        1      171      0      1.5
# 23    61    1   2       150   243    1        1      137      1      1.0
# 25    71    0   1       160   302    0        1      162      0      0.4
# 26    59    1   2       150   212    1        1      157      0      1.6
# 35    46    0   2       142   177    0        0      160      1      1.4
# 37    54    1   2       150   232    0        0      165      0      1.6
# 38    65    0   2       155   269    0        1      148      0      0.8
# ...

# %%
high.trestbps
# Out:
# 0      145
# 8      172
# 9      150
# 14     150
# 17     150
# 18     150
# 23     150
# 25     160
# 26     150
# 35     142
# 37     150
# 38     155
# 39     160
# 83     152
# 95     142
# 100    148
# 101    178
# 106    160
# 110    180
# 111    150
# 127    152
# 130    160
# 145    156
# 147    150
# 150    160
# 152    170
# 153    146
# 165    160
# 179    150
# 181    150
#       ...
# 203    180
# 204    160
# 207    150
# 213    145
# 220    150
# 223    200
# 225    145
# 228    170
# 231    165
# 232    160
# 240    160
# 241    174
# 242    145
# 243    152
# 247    160
# 248    192
# 254    160
# 255    142
# 257    144
# 258    150
# 260    178
# 266    180
# 276    146
# 283    152
# 287    154
# 290    148
# 292    170
# 293    152
# 297    164
# 300    144
# Name: trestbps, Length: 65, dtype: int64

# %%
high.trestbps.value_counts()
# Out:
# 150    17
# 160    11
# 145     5
# 152     5
# 170     4
# 142     3
# 180     3
# 178     2
# 144     2
# 146     2
# 148     2
# 154     1
# 200     1
# 155     1
# 192     1
# 164     1
# 165     1
# 172     1
# 174     1
# 156     1
# Name: trestbps, dtype: int64

# %%
high.trestbps.value_counts().plot(kind='pie')

# %%
 According to the chest pain Type i.e cp

# %%
sns.countplot(New.cp)
plt.xlabel('Chest Type')
plt.ylabel('Count')
plt.title('Chest Type vs Count State')
plt.show()

# %% [markdown]
# 0 Status at least(Noraml peole)
#
# 1 Condition slightly distressed
#
# 2 Condition medium problem
#
# 3 Condition too bad
#
#
#
# -------------------------------------------------------------------------------------------------------------------------------
